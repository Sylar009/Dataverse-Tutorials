# %%
# Using pass Inside Functions
def placeholder_function():
    # Function structure is ready, logic will be added later
    pass

placeholder_function()

# %%
# Using pass in if-else Blocks
score = 85

if score >= 90:
    pass
else:
    print("Score is below excellence level")
# Out:
# Score is below excellence level

# %%
# Using pass Inside Loops
for number in range(1, 6):
    if number == 3:
        pass
    else:
        print(number)
# Out:
# 1
# 2
# 4
# 5

# %%
# Using pass in Classes
class Blueprint:
    pass

class UserProfile:
    def __init__(self, username):
        self.username = username

    def show_profile(self):
        pass
